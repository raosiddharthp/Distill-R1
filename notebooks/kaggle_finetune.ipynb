# %% [markdown]
# # DistillR1 — Kaggle QLoRA Fine-Tuning
# Full training walkthrough on Kaggle T4 (free tier).
# Model: Qwen2.5 7B | Adapter: QLoRA rank=16 | Teacher: Nvidia Nemotron via OpenRouter

# %%
# !pip install -q transformers peft trl accelerate datasets openai pyyaml

# %%
# See pipeline/01_generate.py for data generation
# See pipeline/02_finetune.py for training
# Full steps at github.com/raosiddharthp/Distill-R1
